# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

건설 = pd.read_csv("건설_0208.csv", encoding = 'CP949')

name = list(건설['시명'])
baechul = list(건설['2020 건설폐기물 배출량'])
churi = list(건설['2020 건설폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 건설폐기물', fontsize = 15)
plt.xlabel('지역 내 건설폐기물 배출량 비중', fontsize = 10)
plt.ylabel('지역 내 건설폐기물 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_건설.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

사업장 = pd.read_csv("사업장_0208.csv", encoding = 'CP949')

name = list(사업장['시명'])
baechul = list(사업장['2020 사업장폐기물 배출량'])
churi = list(사업장['2020 사업장폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 사업장폐기물', fontsize = 15)
plt.xlabel('지역 내 사업장폐기물 배출량 비중', fontsize = 10)
plt.ylabel('지역 내 사업장폐기물 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_사업장.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

생활 = pd.read_csv("생활_0208.csv", encoding = 'CP949')

name = list(생활['시명'])
baechul = list(생활['2020 생활폐기물 배출량'])
churi = list(생활['2020 생활폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 생활폐기물', fontsize = 15)
plt.xlabel('지역 내 생활폐기물 배출량 비중', fontsize = 10)
plt.ylabel('지역 내 생활폐기물 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_생활.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

지정 = pd.read_csv("지정_0208.csv", encoding = 'CP949')

name = list(지정['시명'])
baechul = list(지정['2020 지정폐기물 배출량'])
churi = list(지정['2020 지정폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 지정폐기물', fontsize = 15)
plt.xlabel('지역 내 지정폐기물 배출량 비중', fontsize = 10)
plt.ylabel('지역 내 지정폐기물 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_지정.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

건설 = pd.read_csv("건설_유형_0208.csv", encoding = 'CP949')

name = list(건설['시명'])
baechul = list(건설['2020 건설폐기물 배출량'])
churi = list(건설['2020 건설폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 건설폐기물_유형', fontsize = 15)
plt.xlabel('건설폐기물 배출량 지역별 비중', fontsize = 10)
plt.ylabel('건설폐기물 배출량 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_건설_유형.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

사업장 = pd.read_csv("사업장_유형_0208.csv", encoding = 'CP949')

name = list(사업장['시명'])
baechul = list(사업장['2020 사업장폐기물 배출량'])
churi = list(사업장['2020 사업장폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 사업장폐기물_유형', fontsize = 15)
plt.xlabel('사업장폐기물 배출량 지역별 비중', fontsize = 10)
plt.ylabel('사업장폐기물 배출량 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_사업장_유형.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

생활 = pd.read_csv("생활_유형_0208.csv", encoding = 'CP949')

name = list(생활['시명'])
baechul = list(생활['2020 생활폐기물 배출량'])
churi = list(생활['2020 생활폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 생활폐기물_유형', fontsize = 15)
plt.xlabel('생활폐기물 배출량 지역별 비중', fontsize = 10)
plt.ylabel('생활폐기물 배출량 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_생활_유형.png', dpi = 400)

# %%
plt.rcParams["font.size"] = 5
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['xtick.labelsize'] = 8 
plt.rcParams['ytick.labelsize'] = 8

지정 = pd.read_csv("지정_유형_0208.csv", encoding = 'CP949')

name = list(지정['시명'])
baechul = list(지정['2020 지정폐기물 배출량'])
churi = list(지정['2020 지정폐기물 처리량'])

fig, ax = plt.subplots()
ax.scatter(baechul, churi, s = 1)

plt.title('2020년 지정폐기물_유형', fontsize = 15)
plt.xlabel('지정폐기물 배출량 지역별 비중', fontsize = 10)
plt.ylabel('지정폐기물 배출량 처리량 비중', fontsize = 10)

for i, txt in enumerate(name):
    ax.annotate(txt, (baechul[i], churi[i]), rotation=45)

plt.savefig('./2020_지정_유형.png', dpi = 400)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.3.4
# 설치 위치:  C:\Users\Lukaid\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\Lukaid\.matplotlib
# 캐시 위치:  C:\Users\Lukaid\.matplotlib

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  C:\Users\Lukaid\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# ttf 폰트 전체갯수
print(len(font_list))
# Out:
# 727

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# []

# %%
print (plt.rcParams['font.family'] )
# Out:
# ['Malgun Gothic']

# %%
print('test')
# Out:
# test
