# %% [markdown]
# # 쿠팡 스크래핑

# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
#     "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
# }

# url = "https://play.google.com/store/apps/details?id=com.coupang.mobile&showAllReviews=true"
# res = requests.get(url, headers=headers)
# res.raise_for_status()
# soup = BeautifulSoup(res.text, "lxml")

# browser = webdriver.Chrome()
# browser.maximize_window()
# browser.get(url)

# time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

# data = pd.DataFrame(data=[], columns=['num', 'date',
#                     'review', 'rating', 'like'])

# k = 0
# while True:
#     browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
#     time.sleep(2) 
#     browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
#     time.sleep(2)
#     browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
#     time.sleep(2)
#     browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
#     time.sleep(2)
#     while True:
#         try:
#             browser.find_element_by_xpath(
#                 '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
#             k += 1
#             print(f'더보기 횟수 : {k}번')
#             print(f'나타난 리뷰 수 : {40 + k*160}')
#             break
#         except:
#             browser.execute_script(
#                 "window.scrollTo(0, document.body.scrollHeight - 500)")
#             browser.execute_script(
#                 "window.scrollTo(0, document.body.scrollHeight)")
#             time.sleep(2)
#     if k * 160 >= 100000:
#         break


print('데이터 수집 시작')
reviews = browser.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser.find_elements_by_css_selector('.jUL89d')
dates = browser.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data.columns)
    data = pd.concat([data, tmp])
    if i % 100 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data.to_csv('data_coupang.csv', encoding='utf-8-sig')
print('스크래핑 완료')
# Out:
# 데이터 수집 시작
# 객체생성 완료
# 0번째 리뷰 저장 완료
# 100번째 리뷰 저장 완료
# 200번째 리뷰 저장 완료
# 300번째 리뷰 저장 완료
# 400번째 리뷰 저장 완료
# 500번째 리뷰 저장 완료
# 600번째 리뷰 저장 완료
# 700번째 리뷰 저장 완료
# 800번째 리뷰 저장 완료
# 900번째 리뷰 저장 완료
# 1000번째 리뷰 저장 완료
# 1100번째 리뷰 저장 완료
# 1200번째 리뷰 저장 완료
# 1300번째 리뷰 저장 완료
# 1400번째 리뷰 저장 완료
# 1500번째 리뷰 저장 완료
# 1600번째 리뷰 저장 완료
# 1700번째 리뷰 저장 완료
# 1800번째 리뷰 저장 완료
# 1900번째 리뷰 저장 완료
# 2000번째 리뷰 저장 완료
# 2100번째 리뷰 저장 완료
# 2200번째 리뷰 저장 완료
# 2300번째 리뷰 저장 완료
# 2400번째 리뷰 저장 완료
# 2500번째 리뷰 저장 완료
# 2600번째 리뷰 저장 완료
# 2700번째 리뷰 저장 완료
# 2800번째 리뷰 저장 완료
# 2900번째 리뷰 저장 완료
# 3000번째 리뷰 저장 완료
# 3100번째 리뷰 저장 완료
# 3200번째 리뷰 저장 완료
# 3300번째 리뷰 저장 완료
# 3400번째 리뷰 저장 완료
# 3500번째 리뷰 저장 완료
# 3600번째 리뷰 저장 완료
# 3700번째 리뷰 저장 완료
# 3800번째 리뷰 저장 완료
# 3900번째 리뷰 저장 완료
# 4000번째 리뷰 저장 완료
# 4100번째 리뷰 저장 완료
# 4200번째 리뷰 저장 완료
# 4300번째 리뷰 저장 완료
# 4400번째 리뷰 저장 완료
# 4500번째 리뷰 저장 완료
# 4600번째 리뷰 저장 완료
# 4700번째 리뷰 저장 완료
# 4800번째 리뷰 저장 완료
# 4900번째 리뷰 저장 완료
# 5000번째 리뷰 저장 완료
# 5100번째 리뷰 저장 완료
# 5200번째 리뷰 저장 완료
# 5300번째 리뷰 저장 완료
# 5400번째 리뷰 저장 완료
# 5500번째 리뷰 저장 완료
# 5600번째 리뷰 저장 완료
# 5700번째 리뷰 저장 완료
# 5800번째 리뷰 저장 완료
# 5900번째 리뷰 저장 완료
# 6000번째 리뷰 저장 완료
# 6100번째 리뷰 저장 완료
# 6200번째 리뷰 저장 완료
# 6300번째 리뷰 저장 완료
# 6400번째 리뷰 저장 완료
# 6500번째 리뷰 저장 완료
# 6600번째 리뷰 저장 완료
# 6700번째 리뷰 저장 완료
# 6800번째 리뷰 저장 완료
# 6900번째 리뷰 저장 완료
# 7000번째 리뷰 저장 완료
# 7100번째 리뷰 저장 완료
# 7200번째 리뷰 저장 완료
# 7300번째 리뷰 저장 완료
# 7400번째 리뷰 저장 완료
# 7500번째 리뷰 저장 완료
# 7600번째 리뷰 저장 완료
# 7700번째 리뷰 저장 완료
# 7800번째 리뷰 저장 완료
# 7900번째 리뷰 저장 완료
# 8000번째 리뷰 저장 완료
# 8100번째 리뷰 저장 완료
# 8200번째 리뷰 저장 완료
# 8300번째 리뷰 저장 완료
# 8400번째 리뷰 저장 완료
# 8500번째 리뷰 저장 완료
# 8600번째 리뷰 저장 완료
# 8700번째 리뷰 저장 완료
# 8800번째 리뷰 저장 완료
# 8900번째 리뷰 저장 완료
# 9000번째 리뷰 저장 완료
# 9100번째 리뷰 저장 완료
# 9200번째 리뷰 저장 완료
# 9300번째 리뷰 저장 완료
# 9400번째 리뷰 저장 완료
# 9500번째 리뷰 저장 완료
# 9600번째 리뷰 저장 완료
# 9700번째 리뷰 저장 완료
# 9800번째 리뷰 저장 완료
# 9900번째 리뷰 저장 완료
# 10000번째 리뷰 저장 완료
# 10100번째 리뷰 저장 완료
# 10200번째 리뷰 저장 완료
# 10300번째 리뷰 저장 완료
# 10400번째 리뷰 저장 완료
# 10500번째 리뷰 저장 완료
# 10600번째 리뷰 저장 완료
# 10700번째 리뷰 저장 완료
# 10800번째 리뷰 저장 완료
# 10900번째 리뷰 저장 완료
# 11000번째 리뷰 저장 완료
# 11100번째 리뷰 저장 완료
# 11200번째 리뷰 저장 완료
# 11300번째 리뷰 저장 완료
# 11400번째 리뷰 저장 완료
# 11500번째 리뷰 저장 완료
# 11600번째 리뷰 저장 완료
# 11700번째 리뷰 저장 완료
# 11800번째 리뷰 저장 완료
# 11900번째 리뷰 저장 완료
# 12000번째 리뷰 저장 완료
# 12100번째 리뷰 저장 완료
# 12200번째 리뷰 저장 완료
# 12300번째 리뷰 저장 완료
# 12400번째 리뷰 저장 완료
# 12500번째 리뷰 저장 완료
# 12600번째 리뷰 저장 완료
# 12700번째 리뷰 저장 완료
# 12800번째 리뷰 저장 완료
# 12900번째 리뷰 저장 완료
# 13000번째 리뷰 저장 완료
# 13100번째 리뷰 저장 완료
# 13200번째 리뷰 저장 완료
# 13300번째 리뷰 저장 완료
# 13400번째 리뷰 저장 완료
# 13500번째 리뷰 저장 완료
# 13600번째 리뷰 저장 완료
# 13700번째 리뷰 저장 완료
# 13800번째 리뷰 저장 완료
# 13900번째 리뷰 저장 완료
# 14000번째 리뷰 저장 완료
# 14100번째 리뷰 저장 완료
# 14200번째 리뷰 저장 완료
# 14300번째 리뷰 저장 완료
# 14400번째 리뷰 저장 완료
# 14500번째 리뷰 저장 완료
# 14600번째 리뷰 저장 완료
# 14700번째 리뷰 저장 완료
# 14800번째 리뷰 저장 완료
# 14900번째 리뷰 저장 완료
# 15000번째 리뷰 저장 완료
# 15100번째 리뷰 저장 완료
# 15200번째 리뷰 저장 완료
# 15300번째 리뷰 저장 완료
# 15400번째 리뷰 저장 완료
# 15500번째 리뷰 저장 완료
# 15600번째 리뷰 저장 완료
# 15700번째 리뷰 저장 완료
# 15800번째 리뷰 저장 완료
# 15900번째 리뷰 저장 완료
# 16000번째 리뷰 저장 완료
# 16100번째 리뷰 저장 완료
# 16200번째 리뷰 저장 완료
# 16300번째 리뷰 저장 완료
# 16400번째 리뷰 저장 완료
# 16500번째 리뷰 저장 완료
# 16600번째 리뷰 저장 완료
# 16700번째 리뷰 저장 완료
# 16800번째 리뷰 저장 완료
# 16900번째 리뷰 저장 완료
# 17000번째 리뷰 저장 완료
# 17100번째 리뷰 저장 완료
# 17200번째 리뷰 저장 완료
# 17300번째 리뷰 저장 완료
# 17400번째 리뷰 저장 완료
# 17500번째 리뷰 저장 완료
# 17600번째 리뷰 저장 완료
# 17700번째 리뷰 저장 완료
# 17800번째 리뷰 저장 완료
# 17900번째 리뷰 저장 완료
# 18000번째 리뷰 저장 완료
# 18100번째 리뷰 저장 완료
# 18200번째 리뷰 저장 완료
# 18300번째 리뷰 저장 완료
# 18400번째 리뷰 저장 완료
# 18500번째 리뷰 저장 완료
# 18600번째 리뷰 저장 완료
# 18700번째 리뷰 저장 완료
# 18800번째 리뷰 저장 완료
# 18900번째 리뷰 저장 완료
# 19000번째 리뷰 저장 완료
# 19100번째 리뷰 저장 완료
# 19200번째 리뷰 저장 완료
# 19300번째 리뷰 저장 완료
# 19400번째 리뷰 저장 완료
# 19500번째 리뷰 저장 완료
# 19600번째 리뷰 저장 완료
# 19700번째 리뷰 저장 완료
# 19800번째 리뷰 저장 완료
# 19900번째 리뷰 저장 완료
# 20000번째 리뷰 저장 완료
# 20100번째 리뷰 저장 완료
# 20200번째 리뷰 저장 완료
# 20300번째 리뷰 저장 완료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-afb83433384c> in <module>
#      66     tmp = []
#      67     tmp.append(i)
# ---> 68     tmp.append(dates[i].text)
#      69     tmp.append(reviews[i].text)
#      70     tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      72
#      73         if method in self._encode_url_methods:
# ---> 74             return self.request_encode_url(
#      75                 method, url, fields=fields, headers=headers, **urlopen_kw
#      76             )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      94             url += "?" + urlencode(fields)
#      95
# ---> 96         return self.urlopen(method, url, **extra_kw)
#      97
#      98     def request_encode_body(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
data.to_csv('data_coupang.csv', encoding='utf-8-sig')

# %% [markdown]
# - 5시 20분 시작
# - 12시 15분 데이터 수집 시작
# - 14시 27분 객체 생성 완료
# - 15시 16분 800번째 리뷰 저장 완료
# - 16시 27분 1500번째 리뷰 저장 완료
# - 18시 27분 2000번째 리뷰 저장 완료
# - 20시 27분 3100번째 리뷰 저장 완료
# - 22시 27분 5000번째 리뷰 저장 완료
# - 00시 27분 6900번째 리뷰 저장 완료

# %% [markdown]
# # 롯데on 스크래핑

# %%
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
    "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
}

url = "https://play.google.com/store/apps/details?id=com.lotte&showAllReviews=true"

browser_lt = webdriver.Chrome()
browser_lt.maximize_window()
browser_lt.get(url)

time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

data_lt = pd.DataFrame(data=[], columns=['num', 'date', 'review', 'rating', 'like'])

k = 0
while True:
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    while True:
        try:
            browser_lt.find_element_by_xpath(
                '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
            k += 1
            print(f'더보기 횟수 : {k}번')
            print(f'나타난 리뷰 수 : {40 + k*160}')
            break
        except:
            browser_lt.execute_script(
                "window.scrollTo(0, document.body.scrollHeight - 500)")
            browser_lt.execute_script(
                "window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(2)
    if k * 160 >= 20000:
        break

print('데이터 수집 시작')
reviews = browser_lt.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_lt.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_lt.find_elements_by_css_selector('.jUL89d')
dates = browser_lt.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_lt.columns)
    data_lt = pd.concat([data_lt, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_lt.to_csv('data_lt.csv', encoding='utf-8-sig')
# Out:
# 데이터 수집 시작
# 객체생성 완료
# 0번째 리뷰 저장 완료
# 1000번째 리뷰 저장 완료
# 2000번째 리뷰 저장 완료
# 3000번째 리뷰 저장 완료
# 4000번째 리뷰 저장 완료
# 5000번째 리뷰 저장 완료
# 6000번째 리뷰 저장 완료
# 7000번째 리뷰 저장 완료
# 8000번째 리뷰 저장 완료

# %% [markdown]
# # SSG 스크래핑

# %%
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
    "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
}

url = "https://play.google.com/store/apps/details?id=kr.co.ssg&showAllReviews=true"

browser_ssg = webdriver.Chrome()
browser_ssg.maximize_window()
browser_ssg.get(url)

time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

data_ssg = pd.DataFrame(data=[], columns=['num', 'date', 'review', 'rating', 'like'])

k = 0
while True:
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    while True:
        try:
            browser_ssg.find_element_by_xpath(
                '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
            k += 1
            print(f'더보기 횟수 : {k}번')
            print(f'나타난 리뷰 수 : {40 + k*160}')
            break
        except:
            browser_ssg.execute_script(
                "window.scrollTo(0, document.body.scrollHeight - 500)")
            browser_ssg.execute_script(
                "window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(2)
    if k * 160 >= 20000:
        break

print('데이터 수집 시작')
reviews = browser_ssg.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_ssg.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_ssg.find_elements_by_css_selector('.jUL89d')
dates = browser_ssg.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_ssg.columns)
    data_ssg = pd.concat([data_ssg, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_ssg.to_csv('data_ssg.csv', encoding='utf-8-sig')
# Out:
# 더보기 횟수 : 1번
# 나타난 리뷰 수 : 200
# 더보기 횟수 : 2번
# 나타난 리뷰 수 : 360
# 더보기 횟수 : 3번
# 나타난 리뷰 수 : 520
# 더보기 횟수 : 4번
# 나타난 리뷰 수 : 680
# 더보기 횟수 : 5번
# 나타난 리뷰 수 : 840
# 더보기 횟수 : 6번
# 나타난 리뷰 수 : 1000
# 더보기 횟수 : 7번
# 나타난 리뷰 수 : 1160
# 더보기 횟수 : 8번
# 나타난 리뷰 수 : 1320
# 더보기 횟수 : 9번
# 나타난 리뷰 수 : 1480
# 더보기 횟수 : 10번
# 나타난 리뷰 수 : 1640
# 더보기 횟수 : 11번
# 나타난 리뷰 수 : 1800
# 더보기 횟수 : 12번
# 나타난 리뷰 수 : 1960
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-0c11646b7985> in <module>
#      35         try:
# ---> 36             browser_ssg.find_element_by_xpath(
#      37                 '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div"}
#   (Session info: chrome=90.0.4430.72)
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0c11646b7985> in <module>
#      45             browser_ssg.execute_script(
#      46                 "window.scrollTo(0, document.body.scrollHeight)")
# ---> 47             time.sleep(2)
#      48     if k * 160 >= 20000:
#      49         break
#
# KeyboardInterrupt:

# %%
reviews = browser_ssg.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_ssg.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_ssg.find_elements_by_css_selector('.jUL89d')
dates = browser_ssg.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_ssg.columns)
    data_ssg = pd.concat([data_ssg, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_ssg.to_csv('data_ssg.csv', encoding='utf-8-sig')
# Out:
# 객체생성 완료
# 0번째 리뷰 저장 완료
# 1000번째 리뷰 저장 완료
# 2000번째 리뷰 저장 완료
