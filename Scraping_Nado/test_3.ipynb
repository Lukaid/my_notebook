# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd
import numpy as np
import collections as co
import time
import re

# %%
data = pd.DataFrame(data=[], columns=['리뷰', '별점', '날짜'])


driver = webdriver.Chrome("chromedriver.exe")
url = "https://play.google.com/store/apps/details?id=com.coupang.mobile&showAllReviews=true"
driver.get(url)

# %%
def next_page():
    driver.find_element_by_xpath(
        '//div[@class="pf5lIe"]/div[@role="img"]').click()


def scroll_down(driver):
    driver.execute_script("window.scrollTo(0, 999999999999)")
    time.sleep(2)

# %%
def crawl(driver, data):

    # 리뷰, 별점, 날짜 수집
    reviews = driver.find_elements_by_css_selector('.UD7Dzf')
    star_grades = driver.find_elements_by_xpath(
        '//div[@class="pf5lIe"]/div[@role="img"]')
    dates = driver.find_elements_by_css_selector('.p2TkOb')

    i = 0
    k = 0
    while True:
        i += 1
        tmp = []
        tmp.append(reviews[i].text)
        tmp.append(star_grades[i+1].get_attribute('aria-label'))
        tmp.append(dates[i].text)
        # 수집한 1명의 리뷰를 결과 프레임에 추가합니다.
        tmp = pd.DataFrame(data=[tmp], columns=data.columns)
        print(tmp)
        data = pd.concat([data, tmp])

        if i % 20 == 0:
            scroll_down(driver)
            time.sleep(5)
            try:
                driver.find_element_by_xpath(
                        '//div[@class="pf5lIe"]/div[@role="img"]').click()
            except:
                    pass

        if i % 100 == 0:
            data.reset_index(inplace=True, drop=True)
            tmp = data.copy()
            tmp['별점'] = tmp['별점'].apply(lambda x: x[5:])
            m = re.compile('[0-9][\.0-9]*')
            tmp['별점'] = tmp['별점'].apply(lambda x: m.findall(x)[0])
            tmp.to_csv(f'쿠팡_리뷰_평점_{k}.csv', encoding='utf-8')
            k += 1

# %%
crawl(driver, data)
# Out:
#                리뷰                    별점  \
# 0  사용할때마다 튕기네요 확인도 해야하고 사야할 물건도있는데 자꾸 튕겨저서 사용할수가없...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  겁나 잘쓰고 있는데 제품 상세페이지 들어가면 어플종료. 사천성이랑 쿠팡이랑 헬로마켓...  별표 5개 만점에 2개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                              리뷰                    별점  \
# 0  앱 오류 갑자기 오류나네요. 일시적으로 접속할수없다고 뜹니다. 업데이트이후오류남  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 22일
#                                                   리뷰                    별점  \
# 0  접속되었다 마이페이지만 들어가면 꺼짐현상이 몇시간째 이러고있음 빠른시간 복구해주세요...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  결제하려고 하면 자꾸 어플오류로 종료됩니다 이전 버전은 안그랬는데 이번 업데이트하고...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  신상품이 너무없어요 다른앱에서파는 물건보다 질이떨어지고 비싸요 스포츠브랜드는 짝퉁이...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 5일
#                                                   리뷰                    별점  \
# 0  로켓배송으로 날라오니 좋고 무료배송 금액 채우기 편하고 장보기 편해요 요즘은 거의 ...  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 4월 13일
#                                                   리뷰                    별점  \
# 0  판매자와 택배기사분들 피고름짜서 키우는 회사 그분들이 g마켓이나 11번가등으로 갈 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 6일
#                                                   리뷰                    별점  \
# 0  3월23일 오전5시부터 쿠팡엡 오류심각합니다. 검색창열면 엡이 바로 다운됍니다. 구...  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                리뷰                    별점  \
# 0  왜 접속도안되고 재설치도안되고뭡니까??? 주문하던 애기용품주문해야하는데 짜증나네요!  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 6일
#                                                   리뷰                    별점  \
# 0  안녕하세요~^^ 전 엄빠가 화나고 리뷰를 쓰셔서 저도 말하고 싶습니다. 아예 직원들...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 29일
#                                            리뷰                    별점  \
# 0  계속 에러뜨네요. 접속조차도 할수없을지경~안고치고머하십니까?!빨리즘 고치세요  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  앱이 안들어가져요. 데이터 요청만 실패했다고 뜨고 와우쓰고 있고 배송시킬것도 많은데ㅠㅠㅠ  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 4일
#                                                 리뷰                    별점  \
# 0  화면을보면좌.우.로 특화면을봐야 반면반품오늘 혁대끈이 업다니(반품시킬가 생각중입니다)  별표 5개 만점에 3개를 받았습니다.
#
#             날짜
# 0  2021년 4월 2일
#                                                   리뷰                    별점  \
# 0  리뷰 알람은 따로 조정할수잇으면 좋겟네요 시끄러워서 끄면 배달알람까지 꺼져서 이러지...  별표 5개 만점에 5개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                                   리뷰                    별점  \
# 0  쿠팡앱이 그지같이안되네유. 와우 회원인데 뭐 앱이되야 구매를 하져 월 돈은 받아가고...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 28일
#                                                   리뷰                    별점  \
# 0  갑자기 앱실행하면 바로 꺼집니다 계속 지웠다가 다시 깔아도 똑같아요 로켓와우이용자인...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  어제부터앱에서 뭐를살려거하면 오류라고뜨고 검색조차도 하지를못하고있어요 빠른조치부탁드...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 26일
#                                                   리뷰                    별점  \
# 0  앱다시 설치해도 안되고...안드로이든데...뭘해도안되요...다른앱은 다되는데 왜 쿠...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                                   리뷰                    별점  \
# 0  저희동넨 왜 로켓배송 안되죠? 매달 결제는 하고 있는데 로켓배송품 구매해도 최소3일...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 2일
#                                                   리뷰                    별점  \
# 0  앱 먹통됐어요 어제까지 잘되던 앱이 들어가서 클릭만하면 꺼져버리네요 이용이 불편합니...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  일시적 오류로 계속 안들어가져요 첨에 화면은 뜨는데 상품누르면 오류창ㅡㅡ 삭제하고 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 6일
#                                     리뷰                    별점            날짜
# 0  팅겨나간다 다른곳보다 살짝 비싼듯 하다 네이버쇼핑이 더 싼듯하다  별표 5개 만점에 1개를 받았습니다.  2021년 4월 12일
#                                                   리뷰                    별점  \
# 0  갑자기 창이 안열리는데 삭제후 깔아도 안되네요 아랫분도 그래서 와우 해지 했다는데 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 4일
#                                                   리뷰                    별점  \
# 0  앱관리좀해주세요...뭔놈의 네트워크? 다른 싸이트는잘만 되는구민요? 쿠팡앱만 그러합...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  1점도 아깝네요 피해 본 판매자, 과로로 쓰러지시는 택배기사분들.. 안밝혀진 다른 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                              리뷰                    별점  \
# 0  아침 까지도 잘 이용했는데 갑자기 튕기네요 (웹 뷰 때문인지 모르고 죄송합니다)  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  업그레이드후 접속이 안되네요 리뷰분들하고 비슷해여 좋아지려고 업그레이드 했는데 이거...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 5일
#                                                   리뷰                    별점  \
# 0  요즘 쿠팡앱 자꾸 꺼지는데 업뎃하기전엔 괜찮았는데 말이죠 장바구니에 넣는것도 힘들정...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 24일
#                                            리뷰                    별점  \
# 0  계속 '일시적으로 앱에 접속할수없다'고 떠요ㅜㅜ 재설치해도 계속 접속안됩니다  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 22일
#                                                   리뷰                    별점  \
# 0  네트워크에 접속할수 없다는 오류가 갑자기 떠서 android web view 도 종...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 29일
#                                             리뷰                    별점  \
# 0  데이터 접속 실패라고 뜨는데 언제 고쳐줘요? 서비스 너무 대충하는거 아닌가요?  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 4일
#                                                   리뷰                    별점  \
# 0  아이패드 프로 4세대 구입할려고 검색하니 광고비를 얼마나 받았는지 모루겠지만 전부 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                      리뷰                    별점            날짜
# 0  데이터 요청에 실패했다고 어플 실행이 안되네요 다시 고쳐주세요;;  별표 5개 만점에 1개를 받았습니다.  2021년 3월 18일
#                                           리뷰                    별점  \
# 0  갑자기 초기화면에서 아무거나 처음에눌러들어가면 튕깁니다 오류수정 부탁드려요  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                      리뷰                    별점           날짜
# 0  완전만족! 빠른배송과 아주작은상품도 파손이나분실앖이 안전하게도착!  별표 5개 만점에 5개를 받았습니다.  2021년 4월 3일
#                                                  리뷰                    별점  \
# 0  갑자기 오류뜨면서 계속튕겨져나가네요 여기서만쇼핑하는데 왜이러는지...쇼핑하지말라는건가요  별표 5개 만점에 2개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                리뷰                    별점  \
# 0  계속해서 일시적으로 접속할 수 없다고 뜹니다 지웠다 깔아도 이런데 어떻게해야 하나요  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 26일
#                                             리뷰                    별점  \
# 0  구매할 물품을 누르려고 하니까 갑자기 잘안되네요 빨리 해결해주셨으면 좋겠습니다  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                      리뷰                    별점            날짜
# 0  검색정확도양호하고 가격경재력이좋은편임  별표 5개 만점에 5개를 받았습니다.  2021년 4월 14일
#                                               리뷰                    별점  \
# 0  앱 오류로 재설치 반복중 다른 갤럭시 사용자랑 동일한 증상. 1주일째 증상 반복.  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                                   리뷰                    별점  \
# 0  아니ㅡㅡ먼 작은쇼핑몰도 아닌데ㅡㅡ자꾸 팅겨 짜증나게ㅡㅡ더럽게 어플관리못하나?내가여기...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  어제까지 잘되던쿠팡이 켜지기만하고 마이쿠팡이던, 할인정보던 누르기만하면 팅기네요. ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                             리뷰                    별점  \
# 0  쿠팡이 잘되다가 오늘 들어가려니 안되네요 불편합니다 왜안되는건지요 되게해주세요  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  업데이트가 너무 자주되네요 솔직히 귀찮습니다 업데이트는 본사가 알아서 해주셨으면 감...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 3일
#                                                   리뷰                    별점  \
# 0  비(정지훈) 나오는 상단 광고탭 없애버리고 싶은데 왜 자꾸 보여줘요 꼴보기 싫은데 ...  별표 5개 만점에 3개를 받았습니다.
#
#             날짜
# 0  2021년 4월 4일
#                                                   리뷰                    별점  \
# 0  이건 쿠팡문제가 아닐수 있지만. 쿠팡 택배 회사는 뭐하 나요?? 1주일이 넘었는데도...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 7일
#                                                   리뷰                    별점  \
# 0  너무 좋아요! 12월달 돼야 구매 할수 있지만 거의 없는게 없어서 좋아요 저희 어머...  별표 5개 만점에 5개를 받았습니다.
#
#             날짜
# 0  2021년 4월 5일
#                                                  리뷰                    별점  \
# 0  쿠팡 엡접속후 마이쿠팡으로 안들어가지는데 문제가 뭐죠? 두번째 지웠다 키는데... 하.  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  쿠팡 애용자인데 마이쿠팡 들어가서 배송조회 해보려고 터치하니 계속 자동 종료 됩니다...  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  며칠째 쿠팡오류가 해결이 안되네요 실행하면 다른분들과 똑같이 안켜집니다. 물건을 사...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 1일
#                                                   리뷰                    별점  \
# 0  물건을 주문햇으면 그럼 5일안에는와야지 무슨 7일동안 안오냐 환불해도 걸리는시간만 ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 22일
#                                  리뷰                    별점            날짜
# 0  와우가입했는데 별로싼것도없고 비싸요 급할때 새벽배송만좋네요  별표 5개 만점에 2개를 받았습니다.  2021년 4월 11일
#                                     리뷰                    별점            날짜
# 0  잘쓰고있었는데 계속 오류가 나네요 일시적으로 앱에 접근할수없다고  별표 5개 만점에 1개를 받았습니다.  2021년 3월 19일
#                                              리뷰                    별점  \
# 0  갑자기 앱이 오류가 여러번나네요 기종은 갤s10인데 오류때매 재설치만 3번하는중  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 28일
#                                                   리뷰                    별점  \
# 0  왜 화면잠금 해제할때마다 어플이 켜지죠? 설정 바꾸는 것도 없고 찾아보니까 저만 그...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 25일
#                                                   리뷰                    별점  \
# 0  저희 어머니가 마우스를 구메를 했는데 물품 배송중이라 뜨면서 나중어는 물품 계수가 ...  별표 5개 만점에 2개를 받았습니다.
#
#             날짜
# 0  2021년 4월 4일
#                                                   리뷰                    별점  \
# 0  제 인생에서 쿠팡이 저의 1순위 입니다!! 저 정말 쿠팡 없으면 못살아요!!! 정말...  별표 5개 만점에 5개를 받았습니다.
#
#             날짜
# 0  2021년 4월 2일
#                                                리뷰                    별점  \
# 0  앱이 안열려요 데이터요청에 실패했다는데 다른 어플은 잘만 돌아가는데 쿠팡앱만 그래요  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  잠금화면 해제하면 지혼자 앱 켜져있음 ^^; 알림이고 권한이고 다 차단해도 그러는데...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 29일
#                                                   리뷰                    별점  \
# 0  물가에따라 가격이 달라지는거지 그걸 주식이랑 비교하누ㅋㅋㅋ공급하는사람이 단가를 높게...  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 25일
#                                                   리뷰                    별점  \
# 0  어제 새벽까지 이용했는데 갑자기 밖으로 팅겨요 왜죠? 다른분들도 같은평이 많네요 빠...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 24일
#                               리뷰                    별점            날짜
# 0  지금 왜 아침부터 접속이 안되나요,? 후딱해결하시죠!  별표 5개 만점에 1개를 받았습니다.  2021년 3월 30일
#                                   리뷰                    별점           날짜
# 0  엄청 빠른 배송은 좋은데... 배송 기사님들 줌 챙겨주세요!  별표 5개 만점에 3개를 받았습니다.  2021년 4월 4일
#                                             리뷰                    별점  \
# 0  잘 쓰고 있어요 프레시 와우 회원가가 많아 회원 아니면 구입이 안되서 불편해요  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 4월 12일
#                                                   리뷰                    별점  \
# 0  몇년동안 잘쓰고있는데 왜요며칠 앱에서 마이쿠팡만 누르면 앱이저절로 꺼져버리네요 빨리...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                         리뷰                    별점            날짜
# 0  편리하다! 좋은 제품 많고! 근데 내 주문내역을 현재 못 보고 있음..  별표 5개 만점에 1개를 받았습니다.  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  지금까지 잘 사용하다가 갑자기 마이쿠팡. 알림 누르면 앱이 자동으로 꺼져요 제꺼만 ...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  제가 찐초록색 후드집업을 시켰는데요 왜 겁나게 쨍한 색깔에 후드를 보내주신거죠?후드...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 20일
#                                 리뷰                    별점           날짜
# 0  빠르게 배달되며 반품이 까다롭지 않고 잘 되어 좋습니다.  별표 5개 만점에 4개를 받았습니다.  2021년 4월 3일
#                                          리뷰                    별점  \
# 0  순광고에 출처알수없는 제품 어이없는 가격차이 구매하면 사이즈도 모르는지,  별표 5개 만점에 2개를 받았습니다.
#
#              날짜
# 0  2021년 3월 29일
#                                                   리뷰                    별점  \
# 0  플레이스토어 라이브러리에 있는것들 지우고 잘 안쓰는 어플 좀 지우고 쿠팡 앱으로 들...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 26일
#                                                  리뷰                    별점  \
# 0  다른거 다 좋은데 왜 스크롤하면 지 혼자 눌려서 원치않는 상품 들어가지는지 모르겠습니다  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 21일
#                                                  리뷰                    별점  \
# 0  쿠팡화면 뿐만아니라 11번가 지마켓 옥션 다 자동으로 꺼지네요~ 점심시간이라서 그런가?  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                      리뷰                    별점            날짜
# 0  마이쿠팡 클릭하면 꺼지는데 이거 왜 이러는 거죠? 해결해주세요..  별표 5개 만점에 4개를 받았습니다.  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  대단하네요 이메일 비밀번호 바껴서 이메일 인증후 바꿀라했더니 폰번호바껴서 고객센터전...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 29일
#                                                   리뷰                    별점  \
# 0  찜 리스트를 리스트형 말고 썸네일형으로도 볼 수 있었으면 좋겠어요. 예전에 추가한건...  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 24일
#                                                   리뷰                    별점  \
# 0  너무 좋아요~~^^제가 사고 싶은 물건을 쿠팡에 다 팔자나여ㅎ이앱을 악플다는 사람들...  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 3월 17일
#                              리뷰                    별점            날짜
# 0  계속 튕겨요~ 멀할수가없어요!! 노트10플러스입니다  별표 5개 만점에 3개를 받았습니다.  2021년 3월 23일
#                           리뷰                    별점            날짜
# 0  며칠전부터 쿠팡접속이 안돼요 오류인거같은데..  별표 5개 만점에 1개를 받았습니다.  2021년 3월 26일
#                                                   리뷰                    별점  \
# 0  언젠가부터 갑자기 속도가 엄청 느려졌습니다. 다른 영상, 카톡 다 잘 되는데 쿠팡앱...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 17일
#                                                   리뷰                    별점  \
# 0  4점을 준이유는 네이버보다 다 비쌉니다...근데 쿠팡은 좀더 걸러져서 나오는거 같더...  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 28일
#                         리뷰                    별점            날짜
# 0  오류언제고치나요. 몇주째 실행이 안됩니다.  별표 5개 만점에 1개를 받았습니다.  2021년 3월 28일
#                                      리뷰                    별점           날짜
# 0  계속 오류떠서 삭제하고 재설치해도 똑같네요 와우회원 탈퇴해야겠어요  별표 5개 만점에 1개를 받았습니다.  2021년 4월 8일
#                                       리뷰                    별점            날짜
# 0  잘 사용하고있었는데, 며칠전부터 업슬로 접속하면 강제종료가 됩니다.  별표 5개 만점에 2개를 받았습니다.  2021년 3월 19일
#                                리뷰                    별점           날짜
# 0  데이터 오류 계속 뜸 지웠다 깔고 업뎃 다해도 소용없음  별표 5개 만점에 1개를 받았습니다.  2021년 4월 8일
#                                                   리뷰                    별점  \
# 0  정기배송 해지 정말 불편하게 해두셨네요. 해지할 사람은 어차피 해지할텐데 불편함을 ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 2월 15일
#                                                   리뷰                    별점  \
# 0  잘 사용하고 있었는 데.... 갑자기 이상하게 시키지도 않은 물건이 오고 또 앱도 ...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 3월 16일
#                                                   리뷰                    별점  \
# 0  (제안)지금 물건은 구지 급한건 아니라서요, 로켓 아니어도 되는 옵션을 추가해주시길...  별표 5개 만점에 4개를 받았습니다.
#
#              날짜
# 0  2021년 3월 18일
#                                  리뷰                    별점           날짜
# 0  신속한 배달과 원하는 물품 저렴하게 구매할수있어서 좋아요.  별표 5개 만점에 5개를 받았습니다.  2021년 4월 3일
#                                                   리뷰                    별점  \
# 0  어플 자동 켜짐때문에 미치겠음 원래는 안그랬는데 언젠가부터 갑자기.. 두세달 넘은 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 3월 9일
#                                                   리뷰                    별점  \
# 0  지금 쿠팡이 ㅡㅡ 클릭하면 튕기고 바뀌고 왜 그런건지 10시 이전만해도 잘되더니, ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                    리뷰                    별점           날짜
# 0  반품접수도잘해주고가격도착하고좋아요  별표 5개 만점에 5개를 받았습니다.  2021년 4월 2일
#                                            리뷰                    별점  \
# 0  마이쿠팡만 누르면 바로 꺼지네요ㅡㅡ 어제까지는 안그랬는데 다시설치해도 그래요  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 23일
#                                   리뷰                    별점           날짜
# 0  상담사들친절하고문제발생시 신속처리등반품이나중순취소시입금취소등  별표 5개 만점에 5개를 받았습니다.  2021년 4월 2일
#                             리뷰                    별점           날짜
# 0  스트레이트보고 충격받았습니다 다시는 사용안할려구요  별표 5개 만점에 1개를 받았습니다.  2021년 4월 9일
#                                                   리뷰                    별점  \
# 0  To. 쿠팡앱 검색 담당자분께. 검색결과 페이지에서 필터 적용하여 보였던 제품을 단...  별표 5개 만점에 2개를 받았습니다.
#
#              날짜
# 0  2021년 2월 21일
#                                 리뷰                    별점            날짜
# 0  오전까지 잘 됐는데 갑자기 팅기는 현상이 나타나네요 ㅜㅜ  별표 5개 만점에 4개를 받았습니다.  2021년 3월 23일
#                             리뷰                    별점           날짜
# 0  일상생활에 없어서는 안될 필수품이 되었네용~^♡~  별표 5개 만점에 5개를 받았습니다.  2021년 4월 3일
#                                               리뷰                    별점  \
# 0  자꾸 왜 앱에 접속할 수 없다고 뜨나요ㅠㅠ 삭제하고 다시 다운로드해도 똑같네요..  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 3일
#                                           리뷰                    별점  \
# 0  쿠팡 애용자로써 갠적으로 쿠팡이 맘에듭니다 배송도빠르구요 친절하고 좋습니다  별표 5개 만점에 5개를 받았습니다.
#
#             날짜
# 0  2021년 4월 3일
#                                                   리뷰                    별점  \
# 0  폰 자체 네트워크 연결상태는 좋은 상황인데 쿠팡 앱만 응답이 계속 없네요. (메세지...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 2월 18일
#                                                 리뷰                    별점  \
# 0  다른 건 다 되는데 마이쿠팡만 들어가면 앱이 닫히네요... 얼른 고쳐주셨으면 좋겠네요  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 24일
#                                                   리뷰                    별점  \
# 0  진짜 좋아요. 배송도 괜찮고 편리하지만 검색할때 갑자기 줄여서 일부분만 검색되게 하...  별표 5개 만점에 3개를 받았습니다.
#
#              날짜
# 0  2021년 2월 16일
#                                                   리뷰                    별점  \
# 0  유료 멤버쉽을 취소하려면 자기네 앱을 깔고 필요없는 권한까지 덕지덕지 허용 해줘야 ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 30일
#                                  리뷰                    별점            날짜
# 0  갑자기 마이페이지같은 메뉴누르면 앱이자꾸 꺼짐...개빡침.  별표 5개 만점에 1개를 받았습니다.  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  앱이 안깔려요 업데이트가 안되서 삭제후 다시 깔려했는데,도저히 안 깔려요 어제부테 ...  별표 5개 만점에 1개를 받았습니다.
#
#             날짜
# 0  2021년 4월 5일
#                                                   리뷰                    별점  \
# 0  안녕하세요 저는 쇼핑몰 앱을 여러종류 많이 사용해 보았습니다 일단 쿠팡은 배송이 빠...  별표 5개 만점에 5개를 받았습니다.
#
#             날짜
# 0  2021년 2월 4일
#                                                   리뷰                    별점  \
# 0  부재 중일 때 전화도 주지 않고 대문밖에 택배를 놔둠, 다른 사람이 훔쳐가는 말든 ...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 31일
#                                                   리뷰                    별점  \
# 0  새벽배송 너무 짱이고요ㅠㅠ 배송 상태나 그건 기사님에 따라 달라서 복불복이라 가끔 ...  별표 5개 만점에 5개를 받았습니다.
#
#              날짜
# 0  2021년 1월 30일
#                              리뷰                    별점            날짜
# 0  중단이라면서 자꾸 팅겨나오네요 빠른 조치 부탁합니다  별표 5개 만점에 4개를 받았습니다.  2021년 3월 23일
#                                                   리뷰                    별점  \
# 0  왜 안되는거죵ㅠㅠ? 쿠팡프레시 써야하는데 한 3일째 어플로들어갈수가 없고 모바일웹으...  별표 5개 만점에 1개를 받았습니다.
#
#              날짜
# 0  2021년 3월 21일
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-4eebd59db71e> in <module>
# ----> 1 crawl(driver, data)
#
# <ipython-input-39-d99d3c6dd49c> in crawl(driver, data)
#      12         i += 1
#      13         tmp = []
# ---> 14         tmp.append(reviews[i].text)
#      15         tmp.append(star_grades[i+1].get_attribute('aria-label'))
#      16         tmp.append(dates[i].text)
#
# IndexError: list index out of range

# %%
import re

# %%
remove_tag = re.compile('<.*?>')
test = '<p> 와우 친구들 </p>'

# %%
re.sub(remove_tag, '',test)
# Out:
# ' 와우 친구들 '

# %%
test_2 = '\n\n\n\n\n\n와우\n\n\n\n친구들'
remove_break = re.compile('\n')
re.sub(remove_break, '',test_2)
# Out:
# '와우친구들'
