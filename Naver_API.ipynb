# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukaid/my_notebook/blob/main/Naver_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 API

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "VzhDPPl2jYhHHqnnCnXG"
client_secret = "XD20x9HONl"

query = urllib.parse.quote(input('검색 질의: '))
# encText = urllib.parse.quote("컴퓨터") # quote가 문자열을 utf-8으로 변경해줌
idx = 0
display = 100 # 가져올 정보의 개수 , default = 10, max = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns = ('Title', 'Link', 'Description', 'Post Date'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if (rescode==200): # 정상코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            post_data = items[item_index]['postdate']
            web_df.loc[idx] = [title, link, description, post_data]
            idx += 1
    else:
        print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 쿠팡
#                             Title  ...                                        Description
# 0                             쿠팡!  ...             이커머스, 쇼핑몰, 마트, 패션의류/잡화, 뷰티, 여행/레저, 할인.
# 1                       쿠팡 공식 블로그  ...  약 3천 명의 구독자를 보유한 쿠팡 공식 블로그(coupang_kr)의 블로그. 약...
# 2    쿠팡 (Coupang) - Google Play 앱  ...  쿠팡 (Coupang) 쿠팡 쇼핑 572,735 위시리스트에 추가 설치 ▶ '로켓배...
# 3                       쿠팡 - 나무위키  ...  스톤에이지에 대한 내용은 쿠팡(스톤에이지) 문서를 , 인도네시아 도시에 대한 내용은...
# 4                      로켓프레시 - 쿠팡  ...  로켓프레시 (21,434) 쿠팡 랭킹순 설명쿠팡 랭킹순은 판매 실적, 사용자 선호도...
# ..                            ...  ...                                                ...
# 195          딩글스 인형 아트 컬러링북 - 쿠팡!  ...  도서: 딩글스 인형 아트 컬러링 엽서책 저자: 그레이스 드레이튼 ISBN: 8809...
# 196                쿠팡! | 아시아 문화탐험  ...  신청하기 장바구니 담기 바로구매 저자: 편집부 저 ISBN: 880933297159...
# 197    펼치면서 알아보는 숨겨진 곤충지식백과 - 쿠팡!  ...  담기 바로구매 ISBN: 9791158951467 옮긴이/역자: 정성재 그린이: 마...
# ...

# %% [markdown]
# ## 네이버 지식인 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "VzhDPPl2jYhHHqnnCnXG"
client_secret = "XD20x9HONl"

query = urllib.parse.quote(input('검색 질의: '))
# encText = urllib.parse.quote("컴퓨터") # quote가 문자열을 utf-8으로 변경해줌
idx = 0
display = 100 # 가져올 정보의 개수 , default = 10, max = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns = ('Title', 'Link', 'Description', 'Post Date'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" + sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if (rescode==200): # 정상코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            post_data = items[item_index]['postdate']
            kin_df.loc[idx] = [title, link, description, post_data]
            idx += 1
    else:
        print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의: 쿠팡
#                   Title  ...                                        Description
# 0           쿠팡 와우 환불 질문  ...  ... 이번에 쿠팡 와우 멤버십으로 핸드폰을 구입했습니다.... 만약에 환불 신청을...
# 1           쿠팡알바 가능한가욧?  ...  쿠팡은 만19세 이상부터 가능한걸로 알고 있는데 제가 생년월일이 03.02.15 이...
# 2             쿠팡 로켓배송문의  ...  ... 쿠팡 로켓배송에 대한 문의입니다. 쿠팡로켓배송은 쿠팡이 사입해서 직접 판매하...
# 3    쿠팡이츠 배달파트너 소득신고 관련  ...  ... 올해 3월부터 쿠팡이츠 투잡을 하는데 내년 5월에 소득신고해야된다고 하는데 ...
# 4       쿠팡 상장 수혜주를 아는방법  ...  ... 쿠팡이 나스닥에 상장을 한다는 소식이 들리면서 우리나라 쿠팡 관련주들 주가가...
# ..                  ...  ...                                                ...
# 995             쿠팡이츠 부업  ...  ... 받고있습니다 쿠팡이츠 배달로 추가수익을 내고자 하는데, 제가 쿠팡이츠로 돈을...
# 996         쿠팡 아이패드 8세대  ...  쿠팡에 아이패드 8세대 품절이던데 언제쯤 들어올까요ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 쿠팡 아이...
# 997           쿠팡이츠배달파트너  ...  쿠팡이츠배달파트너 이게 직장이 아니고 알바개념 같은건가요? 쿠팡이츠배달파트너 하는방...
# 998             쿠팡 당일배송  ...  쿠팡에서 당일배송 시키면 하루만에 포항까지 배달 되나요 ??  안녕하세요. 문의주신...
# 999     쿠팡 아이패드 8세대 재입고  ...  쿠팡 아이패드 8세대 32기가 골드 와이파이 모델 언제... 정확한 답변을 위해 쿠...
#
# ...

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "VzhDPPl2jYhHHqnnCnXG"
client_secret = "XD20x9HONl"

query = urllib.parse.quote(input('검색 질의: '))
# encText = urllib.parse.quote("컴퓨터") # quote가 문자열을 utf-8으로 변경해줌
idx = 0
display = 100 # 가져올 정보의 개수 , default = 10, max = 100
start = 1
end = 1000
sort = "sim"

blog_df = pd.DataFrame(columns = ('Title', 'Link', 'Description', 'Blogger Name', 'Blogger Link', 'Post Data'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" + sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if (rescode==200): # 정상코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            blogger_name = items[item_index]['bloggername']
            blogger_link = items[item_index]['bloggerlink']
            post_data = items[item_index]['postdate']
            blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_data]
            idx += 1
    else:
        print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의: 쿠팡
#                                    Title  ... Post Data
# 0        쿠팡 파트너스 / 수익발생 글 분석 + 실적상세 엑셀파일  ...  20210412
# 1             페이코인 관련주 다날 주가는 상승중 (쿠팡효과)  ...  20210312
# 2         비 메이킹 영상! 10년만에 쿠팡 광고로 돌아온 정지훈  ...  20210410
# 3                     쿠팡 주식 사는법 가격 전망 정리  ...  20210329
# 4          sk알뜰폰, 쿠팡 알뜰폰유심 셀프 개통하는 방법 공유  ...  20210414
# ..                                   ...  ...       ...
# 995  렌즈 구매를 쿠팡 재포장 제품으로 모험했다. (feat....   ...  20210222
# 996                      쿠팡고객센터 도전하려 한다면  ...  20201126
# 997                  2021.01 쿠팡/배민 지도 오류  ...  20210121
# 998       아이폰 se2 11 시리즈 자급제폰 쿠팡 가격대박 할인  ...  20210127
# 999            에어팟 프로 쿠팡 정품등록까지 내돈내산 성공!  ...  20201225
#
# [1000 rows x 6 columns]

# %%
blog_df.iloc[0]['Link']
# Out:
# 'https://blog.naver.com/philosb?Redirect=Log&logNo=222307717711'

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "VzhDPPl2jYhHHqnnCnXG"
client_secret = "XD20x9HONl"

query = urllib.parse.quote(input('검색 질의: '))
# encText = urllib.parse.quote("컴퓨터") # quote가 문자열을 utf-8으로 변경해줌
idx = 0
display = 100 # 가져올 정보의 개수 , default = 10, max = 100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns = ('Title', 'Link', 'Image', 'Low Price', 'Higj Price', \
                                  'Mall name', 'Product ID', 'Product Type', 'Maker', 'Brand', \
                                  'Category_1', 'Category_2', 'Category_3', 'Category_4'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" + sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if (rescode==200): # 정상코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            lprice = items[item_index]['lprice']
            hprice = items[item_index]['hprice']
            mallName = items[item_index]['mallName']
            productId = items[item_index]['productId']
            productType = items[item_index]['productType']
            maker = items[item_index]['maker']
            brand = items[item_index]['brand']
            category1 = items[item_index]['category1']
            category2 = items[item_index]['category2']
            category3 = items[item_index]['category3']
            category4 = items[item_index]['category4']
            shop_df.loc[idx] = [title, link, image, lprice, hprice, mallName, productId, productType, maker, brand, category1, category2, category3, category4]
            idx += 1
    else:
        print("Error Code:" + rescode)

shop_df
# Out:
# 검색 질의: 쿠팡
#                                                  Title  ... Category_4
# 0    Apple 애플워치 SE  40mm  GPS  실버 알루미늄 케이스  화이트 스포츠 밴드  ...
# 1                        삼성전자 갤럭시워치3 45mm  SM-R840  실버  ...
# 2                       나우푸드 더블 스트랭스 L-아르기닌 1000mg 타블렛  ...   기타건강보조식품
# 3    Apple 애플워치 SE  40mm  GPS  골드 알루미늄 케이스  핑크샌드 스포...  ...
# 4               대상웰라이프 뉴케어 구수한맛 환자영양식 식사대용  200ml  10개  ...  환자식/영양보충식
# ..                                                 ...  ...        ...
# 995                         행복한바오밥 도블 동물원 순발력게임  혼합 색상  ...       보드게임
# 996                            크레앙 파워 스마트폰 거치대  실버  1개  ...
# 997               닥터바르미 베개  텐셀커버  40.5 x 18.5 x 9.5 cm  ...       계절베개
# 998                                레고프렌즈 41314 스테파니의 집  ...         레고
# 999                          엠에스 L형 치간칫솔 SSS  50개입  1개  ...
#
# [1000 rows x 14 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "VzhDPPl2jYhHHqnnCnXG"
client_secret = "XD20x9HONl"

query = urllib.parse.quote(input('검색 질의: '))
# encText = urllib.parse.quote("컴퓨터") # quote가 문자열을 utf-8으로 변경해줌
idx = 0
display = 100 # 가져올 정보의 개수 , default = 10, max = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns = ('Title', 'Original Link', 'Link', 'Descript', 'pubDate'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/news?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" + sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if (rescode==200): # 정상코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubDate = items[item_index]['pubDate']
            news_df.loc[idx] = [title, original_link, link, description, pubDate]
            idx += 1
    else:
        print("Error Code:" + rescode)

news_df
# Out:
# 검색 질의: 쿠팡
#                                                  Title  ...                          pubDate
# 0                    배민·위메프도 '한집 배달'…쿠팡 '메기효과'에 시장 바뀐다  ...  Thu, 15 Apr 2021 15:31:00 +0900
# 1                        쿠팡, 美 상장 5조 투자 본격화…해외 진출 성공할까  ...  Thu, 15 Apr 2021 12:23:00 +0900
# 2                               쿠팡, 경남 창원에서 3200명 채용한다  ...  Thu, 15 Apr 2021 11:30:00 +0900
# 3                              쿠팡, 창원에 신규 일자리 3200개 약속  ...  Thu, 15 Apr 2021 16:21:00 +0900
# 4                             쿠팡, 창원서 내년까지 3200명 신규 채용  ...  Thu, 15 Apr 2021 13:53:00 +0900
# ..                                                 ...  ...                              ...
# 995                              쿠팡 '총수없는 대기업집단' 지정 전망  ...  Tue, 06 Apr 2021 15:42:00 +0900
# 996  KCTC·KTH, 쿠팡 관련주 상승에 급등으로 훨훨…KCTC 8% 급등 이어 KTH...  ...  Wed, 14 Apr 2021 13:29:00 +0900
# 997                    쿠팡, 온라인 판매 금지된 주류 팔다 논란 일자 '중단'  ...  Mon, 05 Apr 2021 20:19:00 +0900
# ...

# %%
news_df.iloc[0]['Descript']
news_df.iloc[0]['Link']
# Out:
# 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004530842'
